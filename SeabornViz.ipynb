# %% [markdown]
# <a href="https://colab.research.google.com/github/Nehankur1/PythonDataVisualization/blob/main/SeabornViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Univariant Plots - distplot
#
# Bivarient Plots - jointplot, pairplot
#
# Categorical Plots - countplot, boxplot, swarmplot, heatmap

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
# or via ; tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Plot on one variable on X Axis i.e. Total Bill # Univarince Observations
sns.distplot(tips['total_bill'])
# Out:
# <ipython-input-9-057ee9cdc291>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'], kde=False)
# Out:
# <ipython-input-10-1979d1a62429>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde=False)
# <Axes: xlabel='total_bill'>

# %%
# Joint plots => Bi Variant Graphs
# Distribution of Total Bill over Tip
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg') #prediction line

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#Pair Plots
# Total_Bill, Tip, Size
# 3 Numeric Columns => 9 graphs
# 4 Numeric Columns => 16 graphs
sns.pairplot(tips)

# %%
# Plot graphs based on categorical columns like sex, smoker, day, time
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='smoker', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='day', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x='time', data=tips)
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
# Box plot
sns.boxplot(x='day', y='tip', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='sex', y='tip', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='smoker', y='tip', data=tips)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.boxplot(x='day', y='tip', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# heat maps
fp = tips.pivot_table(index='tip', columns='day', values='total_bill')
fp
# Out:
# day     Thur   Fri    Sat    Sun
# tip
# 1.00     NaN  5.75   7.64    NaN
# 1.01     NaN   NaN    NaN  16.99
# 1.10     NaN   NaN  12.90    NaN
# 1.17     NaN   NaN  32.83    NaN
# 1.25    8.51   NaN  10.29    NaN
# ...      ...   ...    ...    ...
# 6.70   34.30   NaN    NaN    NaN
# 6.73     NaN   NaN  48.27    NaN
# 7.58     NaN   NaN  39.42    NaN
# 9.00     NaN   NaN  48.33    NaN
# 10.00    NaN   NaN  50.81    NaN
#
# [123 rows x 4 columns]

# %%
sns.heatmap(fp)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
